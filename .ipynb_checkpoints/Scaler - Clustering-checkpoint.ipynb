# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Scaler is an online tech-versity offering intensive computer science & Data Science courses through live classes delivered by tech leaders and subject matter experts. The meticulously structured program enhances the skills of software professionals by offering a modern curriculum with exposure to the latest technologies. It is a product by InterviewBit.
#
# You are working as a data scientist with the analytics vertical of Scaler, focused on profiling the best companies and job positions to work for from the Scaler database. You are provided with the information for a segment of learners and tasked to cluster them on the basis of their job profile, company, and other features. Ideally, these clusters should have similar characteristics.
#
# Hence, as a part of this project we need to cluster some students data based on their similarities with each other. The beauty of a cluster is that similar people are in a cluster and share common characteristics whereas people of two different clusters are different and dissimilar.

# %%
# Loading all the necessary libraries

# for multidimensional array processing
import numpy as np      

# for working with structured dataset
import pandas as pd
pd.options.display.float_format = "{:.2f}".format

# for basic plotting functionalities
import matplotlib.pyplot as plt    

# for plotting advanced graphs
import seaborn as sns  

# to normalize data for getting best linear regression model
from sklearn.preprocessing import StandardScaler

# for using KNN imputation
from sklearn.impute import KNNImputer

# for applying target encoding
from category_encoders import TargetEncoder

# for applying Label encoder
from sklearn.preprocessing import LabelEncoder

# for k means clustering
from sklearn.cluster import KMeans

# for hierarchial clustering
from sklearn.cluster import AgglomerativeClustering

# for DBSCAN
from sklearn.cluster import DBSCAN

# to see progress of operation
from tqdm.notebook import tqdm_notebook

# to suppress any warnings coming out
import warnings                       
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("scaler_clustering.csv")
data.head()
# Out:
#    Unnamed: 0               company_hash  \
# 0           0             atrgxnnt xzaxv
# 1           1  qtrxvzwt xzegwgbb rxbxnta
# 2           2              ojzwnvwnxw vx
# 3           3                  ngpgutaxv
# 4           4                 qxen sqghu
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...  2016.00  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...  2018.00   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...  2015.00  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...  2017.00   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...  2017.00  1400000
#
#          job_position  ctc_updated_year
# 0               Other           2020.00
# 1  FullStack Engineer           2019.00
# 2    Backend Engineer           2020.00
# 3    Backend Engineer           2019.00
# 4  FullStack Engineer           2019.00

# %% [markdown]
# #### 1. Exploratory Data Analysis & Analyzing Basic Metrics

# %%
data.shape
# Out:
# (205843, 7)

# %% [markdown]
# On expecting the shape of the dataframe we can see that there are 205843 rows and 7 columns. Hence, we can say that we are working with a good amount of data
#
# <b> <u> Attribute Information of the Scaler Data </b> </u>
#
# - <b> ‘Unnamed 0’ </b> : Index of the dataset
# - <b> Email_hash </b> : Anonymised Personal Identifiable Information (PII)
# - <b> Company </b> : Current employer of the learner
# - <b> orgyear </b> : Employment start date
# - <b> CTC </b> : Current CTC
# - <b> Job_position </b> : Job profile in the company
# - <b> CTC_updated_year </b> : Year in which CTC got updated (Yearly increments, Promotions)

# %% [markdown]
# On inspecting head and attribute information we can conclude that <b> Unnamed 0 </b> column is not required and can be dropped since it only stores the index of the dataset.

# %%
data.drop(['Unnamed: 0'], axis = 1, inplace = True)
data.head()
# Out:
#                 company_hash  \
# 0             atrgxnnt xzaxv
# 1  qtrxvzwt xzegwgbb rxbxnta
# 2              ojzwnvwnxw vx
# 3                  ngpgutaxv
# 4                 qxen sqghu
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...  2016.00  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...  2018.00   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...  2015.00  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...  2017.00   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...  2017.00  1400000
#
#          job_position  ctc_updated_year
# 0               Other           2020.00
# 1  FullStack Engineer           2019.00
# 2    Backend Engineer           2020.00
# 3    Backend Engineer           2019.00
# 4  FullStack Engineer           2019.00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205843 entries, 0 to 205842
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   company_hash      205799 non-null  object
#  1   email_hash        205843 non-null  object
#  2   orgyear           205757 non-null  float64
#  3   ctc               205843 non-null  int64
#  4   job_position      153281 non-null  object
#  5   ctc_updated_year  205843 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.4+ MB

# %% [markdown]
# On checking the information of data using info() method we can see that there are some null values present in the dataset and especially in <b> job_position </b> column.
#
# Also, column <b> orgyear, ctc, ctc_updated_year </b> are having numeric data while rest are object data types

# %% [markdown]
# <b> Range of Columns </b>

# %%
i = 1

for col in data.columns:
    if data[col].dtype == 'object':
        print(str(i) + '. "' + col + '" is categorical column with total unique values as: ' + str(len(data[col].unique())))
    else:
        print(str(i) + '. "' + col + '" is continuous column with min, max and mean values as: ', data[col].min(), data[col].max(), data[col].mean())
    i += 1
# Out:
# 1. "company_hash" is categorical column with total unique values as: 37300
# 2. "email_hash" is categorical column with total unique values as: 153443
# 3. "orgyear" is continuous column with min, max and mean values as:  0.0 20165.0 2014.8827500400957
# 4. "ctc" is continuous column with min, max and mean values as:  2 1000150000 2271685.0419931696
# 5. "job_position" is categorical column with total unique values as: 1018
# 6. "ctc_updated_year" is continuous column with min, max and mean values as:  2015.0 2021.0 2019.6282312247683

# %%
data.describe().T
# Out:
#                      count       mean         std     min       25%       50%  \
# orgyear          205757.00    2014.88       63.57    0.00   2013.00   2016.00
# ctc              205843.00 2271685.04 11800914.44    2.00 530000.00 950000.00
# ctc_updated_year 205843.00    2019.63        1.33 2015.00   2019.00   2020.00
#
#                         75%           max
# orgyear             2018.00      20165.00
# ctc              1700000.00 1000150000.00
# ctc_updated_year    2021.00       2021.00

# %% [markdown]
# From the describe function we can see that <b> ctc </b> data is very skewed and median (50% quantile) and mean are very different.
#
# Also, <b> orgyear </b> has max value which is 20165 which is wrong as it is an error. Hence, we will remove those rows as we are not sure that whether user wanted to enter 2015 or 2016, so it is better to remove them.
# Also, since
#
# <b> One approach can be to call those students and ask them their current data to update them in master database </b>

# %%
data = data[data['orgyear'] != 20165]

# %%
data.describe().T
# Out:
#                      count       mean         std     min       25%       50%  \
# orgyear          205755.00    2014.71       28.97    0.00   2013.00   2016.00
# ctc              205841.00 2271695.41 11800971.25    2.00 530000.00 950000.00
# ctc_updated_year 205841.00    2019.63        1.33 2015.00   2019.00   2020.00
#
#                         75%           max
# orgyear             2018.00       2204.00
# ctc              1700000.00 1000150000.00
# ctc_updated_year    2021.00       2021.00

# %% [markdown]
# Upon seeing the above statistics of describe function we can see that max values in orgyear is 2204 which is wrong since current year is 2022. Hence, we will try to remove all values where orgyear is more than 2022 to make data logically correct.

# %%
data = data[data['orgyear'] <= 2022]

# %%
data.describe().T
# Out:
#                      count       mean         std     min       25%       50%  \
# orgyear          205419.00    2014.69       28.98    0.00   2013.00   2016.00
# ctc              205419.00 2256715.73 11720192.68    2.00 530000.00 950000.00
# ctc_updated_year 205419.00    2019.63        1.33 2015.00   2019.00   2020.00
#
#                         75%           max
# orgyear             2018.00       2022.00
# ctc              1700000.00 1000150000.00
# ctc_updated_year    2021.00       2021.00

# %% [markdown]
# Also upon inspecting we can see that minimum value in orgyear is 0 and we can check from data that even values 1, 2, 3, ---- to 1900 are present so we will remove all values which are less than 1970 also to make data logical

# %%
data = data[data['orgyear'] >= 1970]

# %% [markdown]
# Now, since our data is statistically correct we will now proceed for further feature engineering steps.

# %% [markdown]
# <font color = 'blue'> <b> Simple Feature Engineering </b> </font>

# %%
data.isna().sum() * 100 / data.shape[0]
# Out:
# company_hash        0.02
# email_hash          0.00
# orgyear             0.00
# ctc                 0.00
# job_position       25.53
# ctc_updated_year    0.00
# dtype: float64

# %% [markdown]
# From the above data we can see that only columns <b> company_hash </b> and <b> job_position </b> contains null values and <b> job_position </b> has around 25% of null values which makes sense since most of the students keep the company and their job title as private.

# %% [markdown]
# One of the techniques to fill null values in column <b> company_hash </b> is to find other entries in the database where company_hash is not null and use those values to fill rows where company_hash is null. <br>
# The technique here would be to use <b> email_hash </b> as if two rows are present one where for email xxx company is a while another row having same email has company missing so we will fill the company with a.

# %%
print("Before applying below method number of Null values: ", data['company_hash'].isna().sum())
# Out:
# Before applying below method number of Null values:  44

# %%
_nullEntries = data[data['company_hash'].isna()]

for row in range(_nullEntries.shape[0]):
    _index = _nullEntries.index[row]
    _notNullEntries = data[data['email_hash'] == _nullEntries['email_hash'].iloc[row]]['company_hash'].values.tolist()
    _notNullEntries = [x for x in _notNullEntries if str(x) != 'nan']
    
    if len(_notNullEntries):
        data['company_hash'].loc[_index] = str(_notNullEntries[0])

# %%
print("After applying above method number of Null values: ", data['company_hash'].isna().sum())
# Out:
# After applying above method number of Null values:  37

# %% [markdown]
# We can see that by using the above technique we have reduced null values in <b> company_hash </b> from 44 to 37. Now, for 37 entries we don't have data so we have no alternative to drop these values as it is very difficult to comment about company for an unkown student.

# %%
data = data[~data['company_hash'].isna()]

# %% [markdown]
# Like above technique we can use the same method to fill null values in column <b> job_position </b>. The aim is to find other entries in the database where job_position is not null and use those values to fill rows where job_position is null. <br>
# The technique here would be to use <b> email_hash </b> as if two rows are present one where for email xxx job is zzzz while another row having same email has job missing so we will fill the company with zzzz.

# %%
print(f"Before applying below method number of Null values: ", data['job_position'].isna().sum())
# Out:
# Before applying below method number of Null values:  52400

# %%
_nullEntries = data[data['job_position'].isna()]

for row in tqdm_notebook(range(_nullEntries.shape[0])):
    _index = _nullEntries.index[row]
    _notNullEntries = data[data['email_hash'] == _nullEntries['email_hash'].iloc[row]]['job_position'].values.tolist()
    _notNullEntries = [x for x in _notNullEntries if str(x) != 'nan']
    
    if len(_notNullEntries):
        data['job_position'].loc[_index] = str(_notNullEntries[-1])
# Out:
#   0%|          | 0/52400 [00:00<?, ?it/s]

# %%
print("After applying above method number of Null values: ", data['job_position'].isna().sum())
# Out:
# After applying above method number of Null values:  21051

# %% [markdown]
# By using above technique we have managed to fill null values in <b> job_position </b> from <b> 52428 </b> to <b> 21051 </b> , hence we have reduced number of nulls by <b> 60 % </b> . <br>
#
# Now, to further handle missing values in column <b> job_position </b> we can use KNN imputation since.
#
# But before applying KNN imputation we need to convert values in column <b> company_hash, email_hash </b> to numbers since KNN imputation needs data to be present in numerical format. For target encoding we will use values of CTC column as it contains salary and it can go perfect with email and company name.

# %%
encoder = TargetEncoder()
print("Total categories in column company_hash are: ", len(data['company_hash'].unique()))
data['company_hash_new'] = encoder.fit_transform(data['company_hash'], data['ctc'])

encoder = TargetEncoder()
print("Total categories in column email_hash are: ", len(data['email_hash'].unique()))
data['email_hash_new'] = encoder.fit_transform(data['email_hash'], data['ctc'])
# Out:
# Total categories in column company_hash are:  37205
# Total categories in column email_hash are:  153013

# %%
data.head()
# Out:
#                 company_hash  \
# 0             atrgxnnt xzaxv
# 1  qtrxvzwt xzegwgbb rxbxnta
# 2              ojzwnvwnxw vx
# 3                  ngpgutaxv
# 4                 qxen sqghu
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...  2016.00  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...  2018.00   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...  2015.00  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...  2017.00   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...  2017.00  1400000
#
#          job_position  ctc_updated_year  company_hash_new  email_hash_new
# 0               Other           2020.00        1116049.23      1411019.66
# 1  FullStack Engineer           2019.00        2197333.62       935830.86
# 2    Backend Engineer           2020.00        2256458.77      1904484.21
# 3    Backend Engineer           2019.00        1713928.57      2256458.77
# 4  FullStack Engineer           2019.00         948810.86      1630337.24

# %% [markdown]
# As we can see from above new dataframe that column <b> company_hash_new </b> and <b> email_hash_new </b> are now numerical since target encoding has been applied to them.
#
# <b> We can also apply label encoding or one hot encoding but with label encoding it would be wrong to give value 1, 2 or 3 to company without knowing its name and in case of one hot encoding it would create large features since total unique values are more here. Hence, target encoding is the best option to go.

# %% [markdown]
# Now, we are one step far from applying KNN imputation to job_position.
#
# Since <b> job_position </b> contains string hence KNN imputation would fail. So, we convert those string values (excluding null) to numbers and then apply KNN imputation.

# %%
data['job_position_new'] = data['job_position']

nonulls = np.array(data['job_position_new'].dropna())

impute_reshape = nonulls.reshape(-1,1)

encoder = TargetEncoder()
impute_reshape = encoder.fit_transform(impute_reshape, data[~data['job_position_new'].isna()]['ctc'])

data['job_position_new'].loc[data['job_position_new'].notnull()] = np.squeeze(impute_reshape)

# %%
imputer = KNNImputer(n_neighbors = 3)
columnsUsedForImputation = ['orgyear', 'ctc', 'job_position_new',
                            'ctc_updated_year', 'company_hash_new', 'email_hash_new']

data['job_position_new'] = pd.DataFrame(imputer.fit_transform(data.loc[:, columnsUsedForImputation]),
                                        columns = columnsUsedForImputation).loc[:, 'job_position_new']

# %% [markdown]
# For doing above method we first converted the data entries in <b> job_position </b> which are not null to numbers using target encoding, since KNN imputation won't work on strings and later for null entries we applied KNN imputation. Hence, we applied 2 way process one for changing non null entries to numbers and then applying KNN imputation with K = 3 (due to high time complexity) for imputing them.

# %% [markdown]
# We can add a new feature called <b> Years_of_experience </b> which can be calculated as current year which is 2022 subtracted by year they started working on.

# %%
data['years_of_experience'] = 2022 - data['orgyear']
data.head()
# Out:
#                 company_hash  \
# 0             atrgxnnt xzaxv
# 1  qtrxvzwt xzegwgbb rxbxnta
# 2              ojzwnvwnxw vx
# 3                  ngpgutaxv
# 4                 qxen sqghu
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...  2016.00  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...  2018.00   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...  2015.00  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...  2017.00   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...  2017.00  1400000
#
#          job_position  ctc_updated_year  company_hash_new  email_hash_new  \
# 0               Other           2020.00        1116049.23      1411019.66
# 1  FullStack Engineer           2019.00        2197333.62       935830.86
# 2    Backend Engineer           2020.00        2256458.77      1904484.21
# 3    Backend Engineer           2019.00        1713928.57      2256458.77
# 4  FullStack Engineer           2019.00         948810.86      1630337.24
#
#    job_position_new  years_of_experience
# 0        3469012.73                 6.00
# 1        1734761.95                 4.00
# 2        1879330.82                 7.00
# 3        1879330.82                 5.00
# 4        1734761.95                 5.00

# %%
data.isna().sum() * 100 / data.shape[0]
# Out:
# company_hash           0.00
# email_hash             0.00
# orgyear                0.00
# ctc                    0.00
# job_position          10.25
# ctc_updated_year       0.00
# company_hash_new       0.00
# email_hash_new         0.00
# job_position_new       0.24
# years_of_experience    0.00
# dtype: float64

# %% [markdown]
# Now since there are <b> % </b> nulls so we can drop them as KNN imputation was itself unable to find them.

# %%
data = data[~data['job_position_new'].isna()]
print(data.shape)
# Out:
# (204835, 10)

# %% [markdown]
# And after doing all operations we are left with only 204835 rows.

# %%
data.drop_duplicates(['company_hash', 'email_hash', 'orgyear', 
                      'ctc', 'job_position', 'ctc_updated_year'],
                    inplace = True)

# %% [markdown]
# Also, we need to remove duplicates but for removing them we need to consider all fields and if all entries in rows are repeating then only we will remove them.

# %% [markdown]
# #### 2. Univariate Analysis

# %%
fig = plt.figure(figsize = (6, 4))

sns.barplot(x = data['company_hash'].value_counts().head(10).index,
            y = data['company_hash'].value_counts().head(10).values.tolist())
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# <b> Observation </b> <br>
# On inspecting the countplot we can see that people from company <b> nvnv wgzohrnvzwj otqcxwto </b> are highest with around 8324 entries.
#
# <b> Recommendation </b>
#
# Since, learners from <b> nvnv wgzohrnvzwj otqcxwto </b> company are highest then we can launch some ads or discount or collaborate with company to attract more learners as most of them might be working in tech stack so they are the right audience to attract.

# %%
data['email_hash'].value_counts().head(10)
# Out:
# 3e5e49daa5527a6d5a33599b238bf9bf31e85b9efa9a94f1c88c5e15a6f31378    9
# bbace3cc586400bbc65765bc6a16b77d8913836cfc98b77c05488f02f5714a4b    9
# 6842660273f70e9aa239026ba33bfe82275d6ab0d20124021b952b5bc3d07e6c    9
# 298528ce3160cc761e4dc37a07337ee2e0589df251d73645aae209b010210eee    8
# c0eb129061675da412b0deb15871dd06ef0d7cd86eb5f7e8cc6a20b0d1938183    8
# 4818edfd67ed8563dde5d083306485d91d19f4f1c95d193a1700e79dd245b75c    8
# b4d5afa09bec8689017d8b29701b80d664ca37b83cb883376b2e95191320da66    7
# f5279f186abfb98a09d85a4467b99863c0bfc91c1147e542d6d23a6a69c9a7be    7
# 5dcd62ab1a606642f3dde6f536f5a343a8e943f215c463f945dd1bad9bff1531    7
# caf66f38a8e742b7690dceb5b02d81ad8be684cfb6dd29b639a385b83748110b    7
# Name: email_hash, dtype: int64

# %% [markdown]
# <b> Observation </b>
#
# We can see that learner from email <b> bbace3cc586400bbc65765bc6a16b77d8913836cfc98b77c05488f02f5714a4b </b> has highest interaction / entries with us.

# %%
fig = plt.figure(figsize = (8, 5))

sns.countplot(data['orgyear'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# <b> Observation </b> <br>
# From above countplot we can see that learners who are part of scaler community have mostly joined organisation in year 2018.
#
# <b> Recommendation </b>
#
# When any new learner is coming to our masterclasses and has orgyear as 2018 then we should spend more energy over him as he is likely that he will buy our course. <br>
# Also, we can collaborate with companies to ask employees who specifically joined them in year 2017 - 19 to take our course for their development.

# %%
fig = plt.figure(figsize = (8, 5))

sns.countplot(data['ctc_updated_year'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# <b> Observation </b>
#
# From previous graph we can see that most people joining company is 2018 and from this graph we can see that most people ctc_updated is year 2019. For year <b> 2020 </b> it is less due to Covid (as most companies give appraisal in April or June and by that time covid attacked).

# %%
fig = plt.figure(figsize = (12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(data['ctc'])

plt.subplot(1, 2, 2)
sns.kdeplot(data['ctc'], fill = True)
plt.show()

# %% [markdown]
# On inspecting the <b> ctc </b> column we can see that there are outliers present in it. Also, when plotting the kdeplot we can see that it is not exactly Normal distribution. <br>
# Now, we will apply IQR method to remove outliers.

# %%
q1 = np.quantile(data['ctc'], 0.25)
q3 = np.quantile(data['ctc'], 0.75)
IQR = q3 - q1
upper_bound = q3 + 1.5 * IQR
lower_bound = q1 - 1.5 * IQR

data = data[(data['ctc'] >= lower_bound) & (data['ctc'] <= upper_bound)]

sns.boxplot(data['ctc'])
plt.show()

# %% [markdown]
# <b> Observation </b>
#
# We can see that post removing outliers from ctc we are getting good data but still some outliers are present. My opinion is not to remove them otherwise we would be left with very few data points and also these outlier points are not much far away hence they are workable.

# %%
fig = plt.figure(figsize = (10, 8))

sns.countplot(data['years_of_experience'])
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# <b> Observation </b>
#
# From above countplot we can say that most people have experience of 3 years (i.e. they joined company in 2018) hence it makes logical sense that people in early year of experience tend to explore more to get financially stable so that is why they are learning new concepts to boost their career.

# %% [markdown]
# #### 3. Bivariate Analysis

# %% [markdown]
# Now, before going for bivariate analysis we can still do some feature engineering as there are lot of values in categorical column and analysing them would be daunting so we will try to categorise company, job etc. in terms of category 1, 2, 3 where 1 means highest tier or administrative job whereas 3 means freshman jobs.

# %%
groupbyData = data.groupby(['company_hash', 'years_of_experience']).mean().ctc.reset_index()
groupbyData.head()
# Out:
#                      company_hash  years_of_experience        ctc
# 0                               0                 2.00  100000.00
# 1                            0000                 5.00  300000.00
# 2                      01 ojztqsj                 6.00  270000.00
# 3                      01 ojztqsj                11.00  830000.00
# 4  05mz exzytvrny uqxcvnt rxbxnta                 3.00 1100000.00

# %% [markdown]
# Now, first we will create flag for designation where if person having ctc more than average ctc of his company with same years of experience then we will categorize him as 1, if ctc is equal to mean then 2 else we will put him in tier 3.
#
# This will help us to make a persona of a person that all learners with <b> designationFlag </b> as 1 are the professionals who are earning good amount.

# %%
data['designationFlag'] = 1

for row in tqdm_notebook(range(data.shape[0])):
    _companyHash = data['company_hash'].iloc[row]
    _jobPosition = data['job_position_new'].iloc[row]
    _yearsofexperience = data['years_of_experience'].iloc[row]
    _ctc = data['ctc'].iloc[row]
    _gdata = groupbyData[(groupbyData['company_hash'] == _companyHash) & (groupbyData['years_of_experience'] == _yearsofexperience)]
    
    if _ctc > _gdata['ctc'].iloc[0]:
        data['designationFlag'].iloc[row] = 3
    
    elif _ctc == _gdata['ctc'].iloc[0]:
        data['designationFlag'].iloc[row] = 2
# Out:
#   0%|          | 0/166397 [00:00<?, ?it/s]

# %% [markdown]
# Secondly, we will find average ctc of learner based on their company and job_position. Any individual earning more than the average ctc must be having high level of experience or their class is 1 (they are elite learners), anyone earning equal to mean is of class 2 and rest is class 3.

# %%
groupbyData = data.groupby(['company_hash', 'job_position_new']).mean().ctc.reset_index()
groupbyData.head()
# Out:
#                      company_hash  job_position_new        ctc
# 0                               0        4297006.39  100000.00
# 1                            0000        2938334.27  300000.00
# 2                      01 ojztqsj        1734761.95  550000.00
# 3  05mz exzytvrny uqxcvnt rxbxnta        3969126.34 1100000.00
# 4                               1        1879330.82  100000.00

# %%
data['classFlag'] = 1

for row in tqdm_notebook(range(data.shape[0])):
    _companyHash = data['company_hash'].iloc[row]
    _jobPosition = data['job_position_new'].iloc[row]
    _yearsofexperience = data['years_of_experience'].iloc[row]
    _ctc = data['ctc'].iloc[row]
    _gdata = groupbyData[(groupbyData['company_hash'] == _companyHash) & (groupbyData['job_position_new'] == _jobPosition)]
    
    if _ctc > _gdata['ctc'].iloc[0]:
        data['classFlag'].iloc[row] = 3
    
    elif _ctc == _gdata['ctc'].iloc[0]:
        data['classFlag'].iloc[row] = 2
# Out:
#   0%|          | 0/166397 [00:00<?, ?it/s]

# %% [markdown]
# At last, we will find average ctc company_wise. We will use this to find learners who are of same company but are earning more than average (to be called as tier 1), equal to average (tier 2) and less than average (tier 3).
#
# Mostly people earning more than average in a company are people at high post or with good years of experience or probably both.

# %%
groupbyData = data.groupby(['company_hash']).mean().ctc.reset_index()
groupbyData.head()
# Out:
#                      company_hash        ctc
# 0                               0  100000.00
# 1                            0000  300000.00
# 2                      01 ojztqsj  550000.00
# 3  05mz exzytvrny uqxcvnt rxbxnta 1100000.00
# 4                               1  175000.00

# %%
data['tierFlag'] = 1

for row in tqdm_notebook(range(data.shape[0])):
    _companyHash = data['company_hash'].iloc[row]
    _ctc = data['ctc'].iloc[row]
    _gdata = groupbyData[(groupbyData['company_hash'] == _companyHash)]
    
    if _ctc > _gdata['ctc'].iloc[0]:
        data['tierFlag'].iloc[row] = 3
    
    elif _ctc == _gdata['ctc'].iloc[0]:
        data['tierFlag'].iloc[row] = 2
# Out:
#   0%|          | 0/166397 [00:00<?, ?it/s]

# %%
data.head()
# Out:
#                 company_hash  \
# 0             atrgxnnt xzaxv
# 1  qtrxvzwt xzegwgbb rxbxnta
# 2              ojzwnvwnxw vx
# 3                  ngpgutaxv
# 4                 qxen sqghu
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...  2016.00  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...  2018.00   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...  2015.00  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...  2017.00   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...  2017.00  1400000
#
#          job_position  ctc_updated_year  company_hash_new  email_hash_new  \
# 0               Other           2020.00        1116049.23      1411019.66
# 1  FullStack Engineer           2019.00        2197333.62       935830.86
# 2    Backend Engineer           2020.00        2256458.77      1904484.21
# 3    Backend Engineer           2019.00        1713928.57      2256458.77
# 4  FullStack Engineer           2019.00         948810.86      1630337.24
#
#    job_position_new  years_of_experience  designationFlag  classFlag  tierFlag
# 0        3469012.73                 6.00                2          2         1
# 1        1734761.95                 4.00                1          1         1
# 2        1879330.82                 7.00                2          2         2
# 3        1879330.82                 5.00                1          1         1
# 4        1734761.95                 5.00                2          2         3

# %% [markdown]
# Now, since we have created 3 different flags now data analysis would be much easier

# %%
sns.countplot(data['designationFlag'])
plt.show()

# %% [markdown]
# <b> Observation </b>
#
# We can say that people who are freshman are more our learners and this holds true because people in early stage of job wants to excel more by learning new techniques so that good hike can be given.

# %%
sns.boxplot(x = data['designationFlag'],
            y = data['ctc'])

plt.show()

# %% [markdown]
# <b> Observation </b> <br>
# The above graph shows that most people who are of tier 3 are earning on an average 15 Lacs per annum.
#
# <b> Recommendation </b>
#
# From above plot we can say that people who are at high post / designation in a company are having high CTC which is around 15 Lacs. <br>
# Hence, scaler should target people who are at good positions for their courses.

# %%
sns.countplot(data['classFlag'])
plt.show()

# %% [markdown]
# <b> Recommendation </b>
#
# We can say that people who are not freshman and not high experienced can be targetted by scaler because they want to become financially stable and the only way is to get a good hike and it is only possible by their upskillment.

# %%
sns.boxplot(x = data['classFlag'],
            y = data['ctc'])

plt.show()

# %% [markdown]
# <b> Observation </b>
#
# From above plot we can say that people who are having high level of experience are earning around 15 Lacs.

# %%
sns.countplot(data['tierFlag'])
plt.show()

# %% [markdown]
# <b> Recommendation </b>
#
# We can say that in same company very few people are earning less than average which means that they are new joining or less years of experience. Hence, we should target more employees of those companies who are at same pace because they are most likely to earn more or upskill themselves.

# %% [markdown]
# #### 4. Manual Clustering

# %% [markdown]
# <b> Recommendation </b>
#
# Hence, one way of clustering users can be based on their <b> designation, company </b> and <b> years_of_experience </b>. <br>
# People who are earning more than average in their company or who are working in good companies like tier 1 companies (google, facebook, amazon etc.) or are working in tech stack (like data science, full stack development technology) are the people whom we should approach and any new learner who lie in these cluster can be advertised as he can purchase our courses.

# %%
sns.scatterplot(x = data['years_of_experience'],
                y = data['ctc'],
                hue = data['designationFlag'])

plt.show()

# %% [markdown]
# On clustering based on <b> years_of_experience </b> and <b> ctc </b> along with <b> designationFlag </b> we clearly see no pattern to differentiate learns based on these attributes

# %%
sns.scatterplot(x = data['years_of_experience'],
                y = data['ctc'],
                hue = data['classFlag'])

plt.show()

# %% [markdown]
# On clustering based on <b> years_of_experience </b> and <b> ctc </b> along with <b> classFlag </b> we clearly see no pattern to differentiate learns based on these attributes

# %%
sns.scatterplot(x = data['years_of_experience'],
                y = data['ctc'],
                hue = data['tierFlag'])

plt.show()

# %% [markdown]
# On clustering based on <b> years_of_experience </b> and <b> ctc </b> along with <b> tierFlag </b> we clearly see no pattern to differentiate learns based on these attributes

# %% [markdown]
# Also, we can use the tier column to find top earning 10 employees in each company and least earning 10 employees in a company

# %%
companyDataTier1 = data[data['tierFlag'] == 1]

counter = 0
for company in companyDataTier1['company_hash'].unique():
    if counter == 5:
        break
    _data = companyDataTier1[companyDataTier1['company_hash'] == company]
    print(f"For company {company} the employees earning more than most of the employees in the company are : ")
    print(_data.sort_values('ctc', ascending = False).head(10)['email_hash'].values.tolist())
    print()
    counter += 1
# Out:
# For company atrgxnnt xzaxv the employees earning more than most of the employees in the company are :
# ['6de0a4417d18ab14334c3f43397fc13b30c35149d70c050c0618caea697c87af', '696f674fbc0d337b20152f91c43082bafaa243da70932c1c543fa3a0e028c63e', 'b4dcd1e7ac426014a32ae303e4b527325d482e4d2c4bef5dda4239da293f3b5c', 'dc8d39f3e9dd9f7576194e1a13c233bfe704bf9a72df994afc99dcfd2e6e14ff', '0d2f25432591093f5907a8681d600f869bbe7c2ae39cd715b06f76c9c192e7da', 'a309a8c6610af7e9f0a88cfb67f9a0095b0dde63475475fad6ba28476f9f98cb']
#
# For company qtrxvzwt xzegwgbb rxbxnta the employees earning more than most of the employees in the company are :
# ['3fde2d8b375672193f1a7a7785ba20d0f47f019f01f104fd6ca9018357665f0a', '53a590c1753474523188b1a2ef2d6480deb24402975d2de43e4fea06f5316139', '931fe7fe5c8b8eeeb5bb528be3c85c196ffcd908da8dbb00d21b9af607754467', '1584b73e38d5e09aa0c1bb03cab49b6720e6688e3dd5abdc7e2ac7e077a98378', 'e73f45f8a717ffd07c6d200899f8dfef329dba2b440d0a6b4cbf938140e134f8', '83bb19f3e15a46c6a6e415f781c5279a2c643b42578ab4d2561d21cd7cd3dbc4', '7e986a2eec24ce1016b70da96076c31c93e200f46da996ba5f45f61bce026253', '9a5f27ac94309ff7f4d1b81dc6aa9b2416a850afba6ac9be584f7f75753e0d6f', 'b7d74ecfdc394e7d8ebbc7f8334fff1b0dc7462a7278fc476c50c516578120e3', 'c1150c3804ca74faecbf803f906ef190b6222dd6a516587faa7bf267a67ed8a5']
#
# For company ngpgutaxv the employees earning more than most of the employees in the company are :
# ['ba15dd061044fb4e36b12087ff6d3946796ca8ac94c2d31b07abb5dc12e57a27', '70d0b7a36b0ae595259cbd7e031216c159575f97ae686164960420e9ef01134e', '239a36724c93932138a4d539dc24abcdc10146ac3a01a11dedcbc14b0715704d', '239a36724c93932138a4d539dc24abcdc10146ac3a01a11dedcbc14b0715704d', 'a8f333c41e160a725fb9c595e4697179983680e7efd3923ae5e072017affcffc', 'c3d5e3bb1cf235d38e2606a19333f1dbf833f83e88f9acd6665cf179a3301cc5', '28800dbc080ff45b27401a175c2660444811367c2daf75194a8e7c1d9bfb77ae', '3f2e3483812c0736d4669f399f7097e7a7bb18449a04361fdc9d579c22d3301d', '400aea75dc1316022b8c4436c60a0646fbea2962e26a5a97d2eb4a62017f83ef', '400aea75dc1316022b8c4436c60a0646fbea2962e26a5a97d2eb4a62017f83ef']
#
# For company yvuuxrj hzbvqqxta bvqptnxzs ucn rna the employees earning more than most of the employees in the company are :
# ['afde569a48687f58f14d6b088bec285b0172cac535c189fc8981da2e762cb39a', '18f2c4aa2ac9dd3ae8ff74f32d30413f5165565b90d8f21a44173a1f73fbb0f2', '18f2c4aa2ac9dd3ae8ff74f32d30413f5165565b90d8f21a44173a1f73fbb0f2', '85ee8e00c0a7738ed2d2ae8fbea98201b69733f48d781c7c387724dbfa8325c8', '85ee8e00c0a7738ed2d2ae8fbea98201b69733f48d781c7c387724dbfa8325c8']
#
# For company lubgqsvz wyvot  wg the employees earning more than most of the employees in the company are :
# ['56cec58246338553b98b9617a14492f2bd73c8f5654f23a548e8dcbd6ddccb85', '7f3e7498a75d4130353f663a82f3c07680733052b855526a234e3c64153b8ae1', '1b621201548996cac5bba303323a5bd99e02c8e121caec58ec13b8d4451cedf1', '134637a7198f37b7d59f7deca59c72e4e1e63f34bf9190e117e5cea331718ada', '45dbff1dad9d7da613f25a4a9812c3ac6dad54c858ef44018b1043508118cc98', '5794bec6e3ee46ffdb464cd55aa9b34a1e5bc3fc05e52cd58570861bed8b8a88', '91ca084e1319a62f9a2620113d2057952f8e5b4d9f60dcd7190d3bf4cc8f6fde', 'c6937a80e2ece243fd7bcbc209f16e163d936b57c757a784723126720953db6a', '2355eea3b2bd999563d62632b01747476d8fb862bb87f62126923c9988e28ef0', 'af75d01ee66ca571941f503a7501b234e94ef7b202fb47232518e7b4645b47e3']

# %% [markdown]
# For the sake of printing I am printing 5 values otherwise notebook would be filled with data only. But we can use it to see all results if I am not breaking at counter 5.

# %%
companyDataTier3 = data[data['tierFlag'] == 3]
counter = 0

for company in companyDataTier3['company_hash'].unique():
    if counter == 5:
        break
    _data = companyDataTier3[companyDataTier3['company_hash'] == company]
    print(f"For company {company} the employees earning less than most of the employees in the company are : ")
    print(_data.sort_values('ctc', ascending = True).head(10)['email_hash'].values.tolist())
    print()
    counter += 1
# Out:
# For company qxen sqghu the employees earning less than most of the employees in the company are :
# ['e6092124b321c70026b718ea529608c617a14da56aa74257fb37be36c4eae9cb', '6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520214b31b95211adb095', '6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520214b31b95211adb095']
#
# For company ngdor ntwy the employees earning less than most of the employees in the company are :
# ['72c2171a022115d475c8faac306912a4c95f6dd7fdd320df09a5e9160d2a8385']
#
# For company bgsrxd the employees earning less than most of the employees in the company are :
# ['fa0b67b15157293101da4d1b1d43084f50c92fdbcfa41cf32c7a6fa5658472e6', 'e0425a113b0354dcfbbd502bc274faaa54a25553e513fd6ea049d807e0b834b2', '5342d3161be69b05b3226ed4f71171538b5691b68f69e484a0cb2c1514e32d32', '5342d3161be69b05b3226ed4f71171538b5691b68f69e484a0cb2c1514e32d32', 'b9c924789a730dca889426b8d849afa84e164420925d3fabfef4b1a242b8b933', '43c449d172e747c5fd1fdc1a2440d74cd059be8bfe523b1aed207a8b7475dc8a', '88171bba1d58c8253f83afa7abe2da2ccb4bfa65d15fba6b9d90b7abaa236626', 'a4ae91e3de110f64fd6787102ae752932ca70295d0c39e940b03ed028279b8a1', '7e05200f63b6dacff7a806eb9bb9acde6304bba912b636bc3f763b2acc9af9d0', '69084dee0e1d3e500352f8b68b719fc0d842ae212ec8572bd14d7745299f7de7']
#
# For company puxn the employees earning less than most of the employees in the company are :
# ['7c796c40fe2dfb8f043dfdd52b7afe032e3c0aa5177b3b7c36fcbec979138005', 'c05a7979d331998dd3feb9ea82e01df7dcbd5806d5aceb96822bb9877201e9fc', 'c5ef2cfec316523c699dee786a00813209d6bf4d416b0c2fd8462c1286e50468', '0b6a0f15c6f237bbdcd082027912be09da38bd8bd99354e09665b0162ec0e6f3', 'a2e9eeafb9910cbee2115d4b59018500a403fc879bcedc3f253af1991562e954', '49dc1a9cf6f057873254235a6bd6e3e4738b33d8ebdcb485f335f967136e5635', '57545ab7edef13d12ef3d21e5159c9d1f0ed43b0c57a50b876af4be0af28430a', '2ea79c3d9df1d68391f935debac99739ab803f532da075ae205b33b007fe8ad5', '176d6d3cfde53758e777659c92a69f02e9a76ac586fd3bce6e87c5d02f2846d8', '08ad6df01d1de6e06cdbe15ee9a68dd0c6ff3b72778513a105a62603d4d31e03']
#
# For company ihvznuyx the employees earning less than most of the employees in the company are :
# ['62cc9b3bfd5113bbe365ab1df817e8739fff379e439f84452f959556543ed086', 'efbcfcb03f3629e36d96e32da7c8d0126204638de2024f490779d5748a4b87a3']

# %% [markdown]
# For the sake of printing I am printing 5 values otherwise notebook would be filled with data only. But we can use it to see all results if I am not breaking at counter 5.

# %% [markdown]
# We can find top 10 companies based on average CTC

# %%
data.groupby('company_hash').mean()[['ctc']].sort_values('ctc', ascending = False).head(10)
# Out:
#                                       ctc
# company_hash
# mvqwrvjo ntwyzgrgsj wtzntq     3420000.00
# st xzahonqxvr                  3410000.00
# ygntrgsxd                      3400000.00
# pqgzgo ojontbo                 3400000.00
# wgatzvnxgz xzzgcvnxgz rvmowzxr 3400000.00
# vxavoy                         3400000.00
# mzjbtrrgz ntwyzgrgsxto         3400000.00
# vagzbg uqxcvnt rxbxnta         3400000.00
# qtte ntwyzgrgsxto              3400000.00
# phrn wgobtnxwo ucn rna         3400000.00

# %% [markdown]
# We can say that above are top 10 companies having mean CTC greater than others

# %%
pd.DataFrame(data.groupby(['company_hash', 'job_position'])['ctc'].apply(lambda grp: grp.nlargest(2).sum()))
# Out:
#                                                        ctc
# company_hash                   job_position
# 0                              Other                100000
# 0000                           Other                300000
# 01 ojztqsj                     Android Engineer     270000
#                                Frontend Engineer    830000
# 05mz exzytvrny uqxcvnt rxbxnta Backend Engineer    1100000
# ...                                                    ...
# zyuw rxbxnta                   Frontend Engineer   2400000
# zyvzwt wgzohrnxzs tzsxzttqo    Frontend Engineer    940000
# zz                             Other               1370000
# zzb ztdnstz vacxogqj ucn rna   FullStack Engineer   600000
# zzzbzb                         Other                720000
#
# [56638 rows x 1 columns]

# %% [markdown]
# <b> Recommendation </b>
#
# Using above result, we can see that mostly see that tech positions are the good paying jobs in each company so we should offer same to each learner to maximise profits.

# %% [markdown]
# #### 5. K means clustering

# %% [markdown]
# Now, we have applied manual clustering and we do not see any good differentiation as we are not combining features together.<br>
# So, we will use unsupervised machine learning called <b> K means clustering </b>
#
# First, we will choose our features from original dataframe

# %%
data.head(2)
# Out:
#                 company_hash  \
# 0             atrgxnnt xzaxv
# 1  qtrxvzwt xzegwgbb rxbxnta
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...  2016.00  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...  2018.00   449999
#
#          job_position  ctc_updated_year  company_hash_new  email_hash_new  \
# 0               Other           2020.00        1116049.23      1411019.66
# 1  FullStack Engineer           2019.00        2197333.62       935830.86
#
#    job_position_new  years_of_experience  designationFlag  classFlag  tierFlag
# 0        3469012.73                 6.00                2          2         1
# 1        1734761.95                 4.00                1          1         1

# %%
X = data[['orgyear', 'ctc',  'ctc_updated_year', 'company_hash_new', 'email_hash_new',
          'job_position_new', 'years_of_experience', 'designationFlag', 'classFlag', 'tierFlag']]

# %%
scaler = StandardScaler()
scaler.fit(X)

X_train = scaler.transform(X)

# %% [markdown]
# For initally we are choosing number of clusters as 3

# %%
k = 3
kmeans = KMeans(n_clusters = k, init = "random", n_init = 2)
y_pred = kmeans.fit_predict(X_train)

clusters = pd.DataFrame(X_train, columns = X.columns)
clusters['label'] = kmeans.labels_
clusters.head(3)
# Out:
#    orgyear   ctc  ctc_updated_year  company_hash_new  email_hash_new  \
# 0     0.19 -0.00              0.37             -0.48           -0.56
# 1     0.69 -0.86             -0.38              0.07           -1.08
# 2    -0.06  1.19              0.37              0.10           -0.02
#
#    job_position_new  years_of_experience  designationFlag  classFlag  \
# 0              1.54                -0.19             0.10       0.10
# 1             -0.58                -0.69            -1.11      -1.17
# 2             -0.40                 0.06             0.10       0.10
#
#    tierFlag  label
# 0     -0.97      0
# 1     -0.97      0
# 2      0.14      2

# %%
clusters['label'].value_counts()
# Out:
# 0    91496
# 2    46005
# 1    28896
# Name: label, dtype: int64

# %%
clusters['label'].value_counts()
# Out:
# 0    91496
# 2    46005
# 1    28896
# Name: label, dtype: int64

# %% [markdown]
# From above data we can see that mostly learners are categorized into cluster 1 (while least are into 0 and 2).
#
# Let us try to plot them to see if they are correct or not

# %%
plt.scatter(clusters['years_of_experience'], clusters['ctc'], c = clusters['label'])
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],  color = "red",
            marker = "X", s = 50)
plt.xlabel('Years of Experience')
plt.ylabel('CTC')
plt.show()

# %%
data['years_of_experience'].max()
# Out:
# 52.0

# %% [markdown]
# <b> Recommendation </b>
#
# From above figure we can clearly see that there are 3 clusters which are self explanatory as learners with high years of experience and high CTC are one cluster (people with high pay and good experience probably mangerial position people) whereas people who are having more CTC and less experience (maybe directors, CEOs, freshers in elite companies) are another cluster and people with less CTC and less expereience (freshers from 2nd or 3rd year) are third cluster.
#
# Hence, we can come up with marketing strategies for learning belonging to respective cluster to ramp up our sales

# %% [markdown]
# Also, we don't know how many clusters to keep so we will use Elbow method for this.

# %%
kmeans_per_k = [KMeans(n_clusters = k, random_state = 42).fit(X_train) for k in range(1, 10)]
inertias = [model.inertia_ for model in kmeans_per_k]
plt.figure(figsize=(12, 8))
plt.plot(range(1, 10), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("WCSS score", fontsize=14)
plt.annotate('Elbow',
             xy = (3, inertias[2]),
             xytext = (0.55, 0.55),
             textcoords = 'figure fraction',
             fontsize = 16,
             arrowprops = dict(facecolor='black', shrink=0.1)
            )
plt.show()

# %% [markdown]
# <b> Recommendation </b>
#
# From above elbow plot we can see that 3 are the optimum number of clusters and which proves are hypothesis that we are having three cluster learners
#
#    - High pay, high years of experience (managerial level people with good experience, who are looking for upskillment or to go at even higher scale)
#    - High pay, less experience (people placed at good MAANG or FAANG companies, who might be looking for upskillment or are lacking industry skills)
#    - Less pay, less experience (our target audience, as they want hike and knowledge so they want scaler courses)

# %% [markdown]
# #### 6. Hierarchial Clustering

# %% [markdown]
# Since, K means clustering is the best option to get inference and can also be used in production for a new learning coming in.
#
# But for pure analysis purpose hierarchial clustering is also used.
#
# Since, our data is too large hence we will try to use sample of data. Due to my configuration I am using 20% fraction of the original data with replacement technique.

# %%
sampleData = X.sample(frac = 0.15, 
                      replace = True, 
                      random_state = 1)
scaler = StandardScaler()
sampleDataScaled = scaler.fit_transform(sampleData)

# %%
hierarchialClustering = AgglomerativeClustering(n_clusters = 3, 
                                                affinity = 'euclidean', 
                                                linkage = 'ward')

y_pred = hierarchialClustering.fit_predict(sampleDataScaled)

clusters = pd.DataFrame(sampleDataScaled, columns = X.columns)
clusters['hier_labels'] = y_pred

# %%
plt.scatter(clusters['years_of_experience'], clusters['ctc'], c = clusters['hier_labels'])
plt.xlabel('Years of Experience')
plt.ylabel('CTC')
plt.show()

# %% [markdown]
# <b> Observation </b>
#
# From hierarchial clustering we can see that there are still 3 clusters and thus it proves that K means was also doing same thing with data

# %% [markdown]
# #### 7. Agglomerative Clustering

# %%
sampleData = X.sample(frac = 0.15, 
                      replace = True, 
                      random_state = 1)
scaler = StandardScaler()
sampleDataScaled = scaler.fit_transform(sampleData)

# %%
dbsc = DBSCAN(eps = 0.3, min_samples = 4).fit(sampleData)
dbscan_labels = dbsc.labels_

clusters = pd.DataFrame(sampleDataScaled, columns = X.columns)
clusters['dbscan_labels'] = dbscan_labels

plt.scatter(clusters['years_of_experience'], clusters['ctc'], c = clusters['dbscan_labels'])
plt.xlabel('Years of Experience')
plt.ylabel('CTC')
plt.show()

# %% [markdown]
# Here, DBSCAN performed worst and thus we can still rely on K means and agglomerative result for categorising learners.

# %% [markdown]
# <b> Recommendation </b>
#
# Using results of K means we can say that there are broadly 3 categories of learners
#
#   - High years of experience and high pay (mostly managerial level)
#   - High pay and less experience (placed in good companies like google , facebook)
#   - Less pay and less experience (our target as they want upskillment and good hike)
